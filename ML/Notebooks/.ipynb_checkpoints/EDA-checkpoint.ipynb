# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../Data/train.csv')

# %%
data.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         5           NaN            0       11       B  184966.930730
# 1         1         240.0            1       16       B  300009.450063
# 2         0         229.0            1        3       B  220925.908524
# 3         3        1084.0            0        5       B  175616.227217
# 4         1        2078.0            2        4       B  150226.531644

# %%
df = data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
#  17  Shops_1        10000 non-null  int64
#  18  Shops_2        10000 non-null  object
#  19  Price          10000 non-null  float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# std        28.560917      5.241148      6.775974  2.005003e+05      0.119025
# min         0.000000      1.000000      0.000000  1.910000e+03      0.000000
# 25%         1.000000      4.000000      9.000000  1.974000e+03      0.017647
# 50%         6.000000      7.000000     13.000000  1.977000e+03      0.075424
# 75%         9.000000     12.000000     17.000000  2.001000e+03      0.195781
# max      2014.000000     42.000000    117.000000  2.005201e+07      0.521867
#
#            Social_1      Social_2      Social_3  Healthcare_1   Helthcare_2  \
# count  10000.000000  10000.000000  10000.000000   5202.000000  10000.000000
# mean      24.687000   5352.157400      8.039200   1142.904460      1.319500
# std       17.532614   4006.799803     23.831875   1021.517264      1.493601
# min        0.000000    168.000000      0.000000      0.000000      0.000000
# 25%        6.000000   1564.000000      0.000000    350.000000      0.000000
# 50%       25.000000   5285.000000      2.000000    900.000000      1.000000
# 75%       36.000000   7227.000000      5.000000   1548.000000      2.000000
# max       74.000000  19083.000000    141.000000   4849.000000      6.000000
#
#             Shops_1          Price
# count  10000.000000   10000.000000
# mean       4.231300  214138.857399
# std        4.806341   92872.293865
# min        0.000000   59174.778028
# 25%        1.000000  153872.633942
# 50%        3.000000  192269.644879
# 75%        6.000000  249135.462171
# max       23.000000  633233.466570

# %%
plt.figure(figsize=(15,9))
sns.boxplot(x=df['Square'])
plt.xticks(np.arange(0, 650, 25))
plt.show()

# %%
df.loc[df['Square'] > 250]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1982   5548          86    5.0  275.645284  233.949309           26.0     12
# 4262     28           9    2.0  604.705972         NaN            1.0     17
# 4690   2307         102    1.0  409.425181  410.639749           10.0      4
# 6977  11602          30    2.0  641.065193  638.163193           10.0     20
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1982        37.0       2011   0.161976         B         A        31
# 4262        18.0       1977   0.161532         B         B        25
# 4690         4.0       2016   0.238617         B         B        26
# 6977        19.0       2019   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1982      7010         5        4508.0            3        7       B
# 4262      5648         1          30.0            2        4       B
# 4690      3889         6         705.0            3        6       B
# 6977      6398       141        1046.0            3       23       B
#
#               Price
# 1982  455264.882666
# 4262  187717.242538
# 4690   90470.430830
# 6977  133529.681562

# %%
IQR = df['Square'].quantile(0.75)-df['Square'].quantile(0.25)
quantile_max = df['Square'].quantile(0.75) + 1.5*IQR
quantile_min = df['Square'].quantile(0.25) - 1.5*IQR

# %%
df_loc_square = df.loc[df['Square'] < quantile_max].loc[df['Square'] > 25]
min_price_square = (df_loc_square['Price']/df_loc_square['Square']).min()

# %%
df_outliers = df.loc[df['Square'] > quantile_max]
df_outliers['min_price'] = df_outliers.loc[:, 'Square']*min_price_square
df_outliers = df_outliers.loc[df_outliers['min_price']>df_outliers['Price']]
# Out:
# <ipython-input-29-6969144e1a07>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_outliers['min_price'] = df_outliers.loc[:, 'Square']*min_price_square

# %%
df = df.drop(df_outliers.index, axis=0)

# %%
index_to_drop = df.loc[df['Square'] < 25].index

# %%
df = df.drop(index_to_drop, axis=0)

# %%
df = df.drop('Healthcare_1', axis=1)

# %%
df['Rooms'][df.loc[df['Rooms']>6].index] = 1
# Out:
# <ipython-input-44-4cd2c92d43df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rooms'][df.loc[df['Rooms']>6].index] = 1

# %%
df = df.drop(df.loc[df['Rooms']<1].index, axis=0)

# %%
df.loc[df['Square']< df['LifeSquare']]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 28     8054          23    1.0   42.530043   43.967759            1.0      3
# 44    10521          38    3.0  104.211396  106.340403            0.0     20
# 52     2301           1    2.0   61.400054   65.224603            0.0     17
# 123    8753          25    3.0   85.952306   89.803753            1.0      4
# 153    9870          62    1.0   51.831473   53.491301            1.0      5
# ...     ...         ...    ...         ...         ...            ...    ...
# 9884     41          30    2.0   59.015896   59.439082           12.0      5
# 9889  12918          23    2.0   51.440463   53.134243           51.0      3
# 9895   2737          27    3.0  123.430072  125.806981          123.0      5
# 9902  14001          73    1.0   44.098768   44.267551            1.0      7
# 9910  16568          27    4.0  200.334539  201.627361           25.0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 28           9.0       2014   0.034656         B         B         0
# 44           0.0       2017   0.060753         B         B        15
# 52          22.0       2016   0.007122         B         B         1
# 123          3.0       2017   0.069753         B         B        53
# 153          1.0       2015   0.072158         B         B         2
# ...          ...        ...        ...       ...       ...       ...
# 9884         5.0       2016   0.000078         B         B        22
# 9889        17.0       2017   0.005767         B         B         1
# 9895        10.0       2015   0.017647         B         B         2
# 9902        24.0       2014   0.042032         B         B        37
# 9910         2.0       2013   0.041116         B         B        53
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 28         168         0            0        0       B   95338.198549
# 44        2787         2            0        7       B  435462.048070
# 52         264         0            0        1       B  199215.452229
# 123      13670         4            1       11       B  309688.592681
# 153        629         1            0        0       A  131797.472284
# ...        ...       ...          ...      ...     ...            ...
# 9884      6398       141            3       23       B  126281.142781
# 9889       388         0            0        0       B   88150.012510
# 9895       469         0            0        0       B  234194.837047
# 9902      6856        84            2        5       B  381937.404161
# 9910     14892         4            1        4       B  528560.506016
#
# [468 rows x 19 columns]

# %%
IQR = df['LifeSquare'].quantile(0.75)-df['LifeSquare'].quantile(0.25)
quantile_max = df['LifeSquare'].quantile(0.75) + 1.5*IQR
quantile_min = df['LifeSquare'].quantile(0.25) - 1.5*IQR

# %%
df.loc[df['LifeSquare'] > df['Square'].max()]
# Out:
#          Id  DistrictId  Rooms     Square   LifeSquare  KitchenSquare  Floor  \
# 4328  16550          27    3.0  81.694417  7480.592129            1.0      9
# 8437  15886          85    3.0  78.059331   461.463614           10.0     12
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4328        17.0       2016   0.017647         B         B         2
# 8437        16.0       1998   0.037178         B         B        52
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 4328       469         0            0        0       B  217357.492366
# 8437     11217         1            1        7       B  394253.299978

# %%
df_2 = df.copy()

# %%
df_2 = df_2.drop(df.loc[df['LifeSquare'] > df['Square'].max()].index, axis=0)

# %%
plt.figure(figsize=(15,9))
sns.boxplot(x=df_2['LifeSquare'])
#plt.xticks(np.arange(0, 650, 25))
plt.show()

# %%
df_2.loc[df_2['LifeSquare'].isna()]['Square']
# Out:
# 7        80.312926
# 8        64.511437
# 21       64.711835
# 23      118.907612
# 25       82.667915
#            ...
# 9985     38.968338
# 9986     64.994245
# 9987     55.620092
# 9994     64.864198
# 9997     47.939008
# Name: Square, Length: 2108, dtype: float64

# %%
k = df_2.fillna(df_2.loc[df_2['LifeSquare'].isna()]['Square'], axis=1)
k.loc[k['LifeSquare'].isna()]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-71-b559b4962ffa> in <module>
# ----> 1 k = df_2.fillna(df_2.loc[df_2['LifeSquare'].isna()]['Square'], axis=1)
#       2 k.loc[k['LifeSquare'].isna()]
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    4319         downcast=None,
#    4320     ) -> Optional["DataFrame"]:
# -> 4321         return super().fillna(
#    4322             value=value,
#    4323             method=method,
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6065             elif isinstance(value, (dict, ABCSeries)):
#    6066                 if axis == 1:
# -> 6067                     raise NotImplementedError(
#    6068                         "Currently only can fill "
#    6069                         "with dict/Series column "
#
# NotImplementedError: Currently only can fill with dict/Series column by column

# %%
plt.figure(figsize=(15,15))
cmap = sns.diverging_palette(240, 10, as_cmap=True)
sns.heatmap(df_2.corr(), annot=True, cmap=cmap)
# Out:
# <AxesSubplot:>
