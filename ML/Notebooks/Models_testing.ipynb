# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error

from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor

# %%
train_data_linear_p2 = pd.read_csv('../Data/train_data_with_feats_p2.csv')
test_data_linear_p2 = pd.read_csv('../Data/test_data_with_feats_p2.csv')
train_data_linear_p3 = pd.read_csv('../Data/train_data_with_feats_p3.csv')
test_data_linear_p3 = pd.read_csv('../Data/test_data_with_feats_p3.csv')
train_data_ne = pd.read_csv('../Data/train_data_with_feats.csv')
test_data_ne = pd.read_csv('../Data/test_data_with_feats.csv')

# %%
cat_feats = ['Ecology_2', 'Ecology_3', 'Shops_2']

# %%
for cat in cat_feats:
    print(f'{cat}: {train_data_ne[cat].unique()}')
# Out:
# Ecology_2: ['B' 'A']
# Ecology_3: ['A' 'B']
# Shops_2: ['B' 'A']

# %%
def cat_feats_encode(df, cat_feats):
    result = df.copy()
    for cat in cat_feats:
        result[cat] = result[cat].replace({'A': 0, 'B': 1})
    return result

# %%
train_data_linear_p2 = cat_feats_encode(train_data_linear_p2, cat_feats)
test_data_linear_p2 = cat_feats_encode(test_data_linear_p2, cat_feats)
train_data_linear_p3 = cat_feats_encode(train_data_linear_p3, cat_feats)
test_data_linear_p3 = cat_feats_encode(test_data_linear_p3, cat_feats)
train_data = cat_feats_encode(train_data_ne, cat_feats)
test_data = cat_feats_encode(test_data_ne, cat_feats)

# %%
y_train = train_data['Price']
y_test = test_data['Price']

# %% [markdown]
# В качестве бейзлайна возьмем среднее значение целевой переменной.

# %%
def baseline_model(y):
    result = y.apply(lambda x: y.mean())
    return result

# %%
y_b_train = baseline_model(y_train)
y_b_test = baseline_model(y_test)

# %%
mse_b_train = mean_squared_error(y_train, y_b_train)
mse_b_test = mean_squared_error(y_test, y_b_test)
r2_b_train = r2_score(y_train, y_b_train)
r2_b_test = r2_score(y_test, y_b_test)

# %%
models_results = pd.DataFrame({'Model': ['Baseline'], 'CV_MSE': ['NaN'], 'CV_RMSE': ['NaN'], 'CV_R2': ['NaN'], 'MSE_train': [mse_b_train], 'RMSE_train': [mse_b_train**0.5], 
                             'MSE_test': [mse_b_test], 'RMSE_test': [mse_b_test**0.5], 'R2_train': [r2_b_train], 
                              'R2_test': [r2_b_test]})

# %%
models_results
# Out:
#       Model CV_MSE CV_RMSE CV_R2     MSE_train    RMSE_train      MSE_test  \
# 0  Baseline    NaN     NaN   NaN  8.593945e+09  92703.532793  8.607589e+09
#
#       RMSE_test  R2_train  R2_test
# 0  92777.092629       0.0      0.0

# %%
X_train_linear_p2 = train_data_linear_p2.drop(['DistrictId', 'Price'], axis=1)
X_test_linear_p2 = test_data_linear_p2.drop(['DistrictId', 'Price'], axis=1)

# %%
X_train_linear_p3 = train_data_linear_p3.drop(['DistrictId', 'Price'], axis=1)
X_test_linear_p3 = test_data_linear_p3.drop(['DistrictId', 'Price'], axis=1)

# %%
X_train = train_data.drop(['DistrictId', 'Price'], axis=1)
X_test = test_data.drop(['DistrictId', 'Price'], axis=1)

# %%
X_test_linear = X_test.copy()
X_test_linear['1'] = 1
X_train_linear = X_train.copy()
X_train_linear['1'] = 1

# %%
num_feats = [x for x in X_train.columns if x not in cat_feats]

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
st_scaler = StandardScaler()
mm_scaler = MinMaxScaler()
r_scaler = RobustScaler()
scalers = [st_scaler, mm_scaler, r_scaler, 'None']

# %%
data_list = [('Data_lr', X_train_linear, X_test_linear, y_train, y_test), ('Data', X_train, X_test, y_train, y_test), 
             ('Data_p2', X_train_linear_p2, X_test_linear_p2, y_train, y_test), 
             ('Data_p3', X_train_linear_p3, X_test_linear_p3, y_train, y_test)]

# %%
data_list[0]
# Out:
# ('Data_lr',
#        Rooms      Square  KitchenSquare  Floor  HouseFloor  HouseYear  \
#  0       2.0   40.320370            6.0    3.0        12.0       1966
#  1       2.0   38.220579            7.0    9.0         9.0       1968
#  2       1.0   86.988870            1.0    8.0         8.0       1977
#  3       2.0   40.075940            5.0    5.0         5.0       1962
#  4       4.0  101.392298           10.0   17.0        22.0       1998
#  ...     ...         ...            ...    ...         ...        ...
#  6969    1.0   47.929851            1.0   11.0        11.0       1977
#  6970    3.0   76.157858            9.0   17.0        22.0       1986
#  6971    3.0   65.904217            7.0    8.0        12.0       1976
#  6972    2.0   60.299356            1.0    5.0         5.0       1977
#  6973    1.0   36.854948            9.0    1.0        12.0       1969
#
#        Ecology_1  Ecology_2  Ecology_3  Social_1  ...  log_Square  \
#  0      0.307467          1          0        30  ...    3.696857
#  1      0.130618          1          1        39  ...    3.643374
#  2      0.060753          1          1        15  ...    4.465780
#  3      0.122090          1          1        29  ...    3.690776
#  4      0.089040          1          1        33  ...    4.618997
#  ...         ...        ...        ...       ...  ...         ...
#  6969   0.017647          1          1         2  ...    3.869739
#  6970   0.238617          1          1        26  ...    4.332808
#  6971   0.136244          1          1        11  ...    4.188202
#  6972   0.072158          1          1         2  ...    4.099321
#  6973   0.033494          1          1        66  ...    3.606990
#
#        log_KitchenSquare  exp_Ecology_1  exp_Helthcare_2  cluster  \
#  0              1.791759       1.359975         7.389056        2
#  1              1.945910       1.139532         2.718282        2
#  2              0.000000       1.062636         1.000000        0
#  3              1.609438       1.129856        54.598150        2
#  4              2.302585       1.093124         1.000000        1
#  ...                 ...            ...              ...      ...
#  6969           0.000000       1.017804         1.000000        0
#  6970           2.197225       1.269492        20.085537        1
#  6971           1.945910       1.145962         1.000000        0
#  6972           0.000000       1.074825         1.000000        0
#  6973           2.197225       1.034061        20.085537        2
#
#        Square_div_Rooms  KitchenSquare_div_Square  KitchenSquare_div_Rooms  \
#  0            20.160185                  0.148808                 3.000000
#  1            19.110290                  0.183147                 3.500000
#  2            86.988870                  0.011496                 1.000000
#  3            20.037970                  0.124763                 2.500000
#  4            25.348074                  0.098627                 2.500000
#  ...                ...                       ...                      ...
#  6969         47.929851                  0.020864                 1.000000
#  6970         25.385953                  0.118176                 3.000000
#  6971         21.968072                  0.106215                 2.333333
#  6972         30.149678                  0.016584                 0.500000
#  6973         36.854948                  0.244201                 9.000000
#
#        Floor_div_HouseFloor  1
#  0                 0.250000  1
#  1                 1.000000  1
#  2                 1.000000  1
#  3                 1.000000  1
#  4                 0.772727  1
#  ...                    ... ..
#  6969              1.000000  1
#  6970              0.772727  1
#  6971              0.666667  1
#  6972              1.000000  1
#  6973              0.083333  1
#
#  [6974 rows x 84 columns],
#        Rooms     Square  KitchenSquare  Floor  HouseFloor  HouseYear  \
#  0       2.0  78.230578            1.0   15.0        22.0       2018
#  1       3.0  69.562638            7.0    9.0         9.0       1972
#  2       2.0  49.451697            5.0    2.0         5.0       1965
#  3       2.0  60.503248            1.0   16.0        16.0       1977
#  4       1.0  46.887892            1.0   12.0        20.0       1977
#  ...     ...        ...            ...    ...         ...        ...
#  2984    1.0  40.717990            1.0    3.0         4.0       1977
#  2985    3.0  78.116626           10.0    7.0        15.0       1982
#  2986    3.0  84.955385           10.0   15.0        15.0       2008
#  2987    1.0  40.655911            9.0    5.0        16.0       1975
#  2988    2.0  54.175502            8.0    8.0        12.0       1984
#
#        Ecology_1  Ecology_2  Ecology_3  Social_1  ...  log_Square  \
#  0      0.195781          1          1        23  ...    4.359661
#  1      0.089040          1          1        33  ...    4.242228
#  2      0.307467          1          0        30  ...    3.900996
#  3      0.034656          1          1         0  ...    4.102697
#  4      0.007122          1          1         1  ...    3.847759
#  ...         ...        ...        ...       ...  ...         ...
#  2984   0.034656          1          1         0  ...    3.706670
#  2985   0.000078          1          1        22  ...    4.358203
#  2986   0.437885          1          1        23  ...    4.442126
#  2987   0.050756          1          1        24  ...    3.705144
#  2988   0.000070          1          1        46  ...    3.992229
#
#        log_KitchenSquare  exp_Ecology_1  exp_Helthcare_2  cluster  \
#  0              0.000000       1.216261        20.085537        0
#  1              1.945910       1.093124         1.000000        1
#  2              1.609438       1.359975         7.389056        2
#  3              0.000000       1.035264         1.000000        0
#  4              0.000000       1.007148         1.000000        0
#  ...                 ...            ...              ...      ...
#  2984           0.000000       1.035264         1.000000        2
#  2985           2.302585       1.000078        20.085537        1
#  2986           2.302585       1.549427         1.000000        1
#  2987           2.197225       1.052066         1.000000        2
#  2988           2.079442       1.000070         2.718282        1
#
#        Square_div_Rooms  KitchenSquare_div_Square  KitchenSquare_div_Rooms  \
#  0            39.115289                  0.012783                 0.500000
#  1            23.187546                  0.100629                 2.333333
#  2            24.725848                  0.101109                 2.500000
#  3            30.251624                  0.016528                 0.500000
#  4            46.887892                  0.021327                 1.000000
#  ...                ...                       ...                      ...
#  2984         40.717990                  0.024559                 1.000000
#  2985         26.038875                  0.128014                 3.333333
#  2986         28.318462                  0.117709                 3.333333
#  2987         40.655911                  0.221370                 9.000000
#  2988         27.087751                  0.147668                 4.000000
#
#        Floor_div_HouseFloor  1
#  0                 0.681818  1
#  1                 1.000000  1
#  2                 0.400000  1
#  3                 1.000000  1
#  4                 0.600000  1
#  ...                    ... ..
#  2984              0.750000  1
#  2985              0.466667  1
#  2986              1.000000  1
#  2987              0.312500  1
#  2988              0.666667  1
#
#  [2989 rows x 84 columns],
#  0       186255.865539
#  1       184294.691755
#  2       374010.267117
#  3       208049.052146
#  4       559215.446005
#              ...
#  6969    144180.480551
#  6970    423176.914878
#  6971    218846.768907
#  6972    192309.274140
#  6973    147017.758061
#  Name: Price, Length: 6974, dtype: float64,
#  0       372016.922629
#  1       378595.041335
#  2       183592.136877
#  3       229778.057902
#  4       160400.401732
#              ...
#  2984     78606.777118
#  2985    447734.909299
#  2986    358673.746366
#  2987    184379.767470
#  2988    247065.228609
#  Name: Price, Length: 2989, dtype: float64)

# %%
feats_not_to_scale = cat_feats[:]
feats_not_to_scale.append('1')

# %%
from sklearn.model_selection import cross_validate

# %%
from sklearn.base import clone

# %%
model_lr = LinearRegression()
model_catboost = CatBoostRegressor(silent=True)
model_forest = RandomForestRegressor()
model_lightgbm = LGBMRegressor()

# %%
def model_fit_results(estimator, model_name, data_list, scaler_list, feats_not_to_scale, df_for_results):
    df_res = df_for_results.copy()
    for name, X_train, X_test, y_train, y_test in data_list:
        feats_to_scale = [x for x in X_train.columns if x not in feats_not_to_scale]
        for sc in scaler_list:
            if not isinstance(sc, str):
                scaler = clone(sc)              
                X_train_scaled = np.hstack((scaler.fit_transform(X_train[feats_to_scale]), X_train.drop(feats_to_scale, axis=1).values))
                X_test_scaled = np.hstack((scaler.transform(X_test[feats_to_scale]), X_test.drop(feats_to_scale, axis=1).values))
                scaler_name = scaler.__str__()[:-2]
            elif sc == 'None':
                X_train_scaled = X_train
                X_test_scaled = X_test
                scaler_name = sc
            model = clone(estimator)
            model_cv_results = cross_validate(model, X_train_scaled, y_train, cv=3, scoring=['r2', 'neg_mean_squared_error'])
            model.fit(X_train_scaled, y_train)
            y_pred_train = model.predict(X_train_scaled)
            y_pred_test = model.predict(X_test_scaled)
            model_mse_train = mean_squared_error(y_train, y_pred_train)
            model_mse_test = mean_squared_error(y_test, y_pred_test)
            r2_train = r2_score(y_train, y_pred_train)
            r2_test = r2_score(y_test, y_pred_test)
            model_results = pd.DataFrame({'Model': [model_name + '+' + name + '+' + scaler_name], 'CV_MSE': [abs(model_cv_results['test_neg_mean_squared_error'].mean())], 
                                  'CV_RMSE': [abs(model_cv_results['test_neg_mean_squared_error'].mean())**0.5], 
                                  'CV_R2': [model_cv_results['test_r2'].mean()], 'MSE_train': [model_mse_train], 
                                  'RMSE_train': [model_mse_train**0.5], 
                                  'MSE_test': [model_mse_test], 'RMSE_test': [model_mse_test**0.5], 'R2_train': [r2_train], 
                              'R2_test': [r2_test]})
            df_res = pd.concat([df_res, model_results], axis=0)
    
    return df_res

# %%
# %%time
models_results = model_fit_results(model_lr, 'LinearRegression', data_list, scalers, feats_not_to_scale, models_results)
# Out:
# Wall time: 3.22 s

# %%
models_results
# Out:
#                                      Model       CV_MSE  CV_RMSE     CV_R2  \
# 0                                 Baseline          NaN      NaN       NaN
# 0  LinearRegression+Data_lr+StandardScaler  3.63928e+09  60326.4  0.576941
# 0    LinearRegression+Data_lr+MinMaxScaler  3.64152e+09    60345  0.576679
# 0    LinearRegression+Data_lr+RobustScaler  3.63946e+09    60328  0.576915
# 0            LinearRegression+Data_lr+None  3.64017e+09  60333.8  0.576834
# 0     LinearRegression+Data+StandardScaler  3.64028e+09  60334.7  0.576822
# 0       LinearRegression+Data+MinMaxScaler   3.6413e+09  60343.2  0.576703
# 0       LinearRegression+Data+RobustScaler   3.6392e+09  60325.8  0.576944
# 0               LinearRegression+Data+None  3.63981e+09  60330.8  0.576875
# 0  LinearRegression+Data_p2+StandardScaler  3.08014e+09  55499.1   0.64224
# 0    LinearRegression+Data_p2+MinMaxScaler  3.07995e+09  55497.3  0.642264
# 0    LinearRegression+Data_p2+RobustScaler  3.08027e+09  55500.2  0.642226
# 0            LinearRegression+Data_p2+None  3.08025e+09    55500  0.642228
# 0  LinearRegression+Data_p3+StandardScaler  6.61589e+09  81338.1  0.223893
# 0    LinearRegression+Data_p3+MinMaxScaler  6.61594e+09  81338.4  0.223885
# 0    LinearRegression+Data_p3+RobustScaler  6.61564e+09  81336.6  0.223919
# 0            LinearRegression+Data_p3+None  6.61592e+09  81338.3  0.223888
#
#       MSE_train    RMSE_train      MSE_test     RMSE_test  R2_train   R2_test
# 0  8.593945e+09  92703.532793  8.607589e+09  92777.092629  0.000000  0.000000
# 0  3.429410e+09  58561.160775  4.250756e+09  65197.825703  0.600950  0.506162
# 0  3.430432e+09  58569.890956  4.238983e+09  65107.470545  0.600832  0.507530
# 0  3.429926e+09  58565.572984  4.239003e+09  65107.628694  0.600890  0.507527
# 0  3.429308e+09  58560.291135  4.238063e+09  65100.403463  0.600962  0.507637
# 0  3.430676e+09  58571.975264  4.239123e+09  65108.544625  0.600803  0.507513
# 0  3.430781e+09  58572.866267  4.247854e+09  65175.560630  0.600791  0.506499
# 0  3.429926e+09  58565.572984  4.239003e+09  65107.628694  0.600890  0.507527
# 0  3.429517e+09  58562.078999  4.238075e+09  65100.501558  0.600938  0.507635
# 0  2.669495e+09  51667.155766  3.577984e+09  59816.250570  0.689375  0.584322
# 0  2.669454e+09  51666.755107  3.578128e+09  59817.457369  0.689380  0.584305
# 0  2.669508e+09  51667.277223  3.578931e+09  59824.165579  0.689373  0.584212
# 0  2.669497e+09  51667.179548  3.577963e+09  59816.077546  0.689375  0.584325
# 0  2.072165e+09  45521.042618  7.819983e+09  88430.669729  0.758881  0.091501
# 0  2.072203e+09  45521.461764  7.821388e+09  88438.610730  0.758876  0.091338
# 0  2.072171e+09  45521.102558  7.819300e+09  88426.806157  0.758880  0.091581
# 0  2.072166e+09  45521.055510  7.819960e+09  88430.539925  0.758881  0.091504

# %%
scalers_for_gb = ['None']

# %%
# %%time
models_results = model_fit_results(model_catboost, 'CatBoostRegressor_encoded', [data_list[1]], scalers_for_gb, feats_not_to_scale, models_results)
# Out:
# Wall time: 17.5 s

# %%
models_results
# Out:
#                                      Model       CV_MSE  CV_RMSE     CV_R2  \
# 0                                 Baseline          NaN      NaN       NaN
# 0  LinearRegression+Data_lr+StandardScaler  3.63928e+09  60326.4  0.576941
# 0    LinearRegression+Data_lr+MinMaxScaler  3.64152e+09    60345  0.576679
# 0    LinearRegression+Data_lr+RobustScaler  3.63946e+09    60328  0.576915
# 0            LinearRegression+Data_lr+None  3.64017e+09  60333.8  0.576834
# 0     LinearRegression+Data+StandardScaler  3.64028e+09  60334.7  0.576822
# 0       LinearRegression+Data+MinMaxScaler   3.6413e+09  60343.2  0.576703
# 0       LinearRegression+Data+RobustScaler   3.6392e+09  60325.8  0.576944
# 0               LinearRegression+Data+None  3.63981e+09  60330.8  0.576875
# 0  LinearRegression+Data_p2+StandardScaler  3.08014e+09  55499.1   0.64224
# 0    LinearRegression+Data_p2+MinMaxScaler  3.07995e+09  55497.3  0.642264
# 0    LinearRegression+Data_p2+RobustScaler  3.08027e+09  55500.2  0.642226
# 0            LinearRegression+Data_p2+None  3.08025e+09    55500  0.642228
# 0  LinearRegression+Data_p3+StandardScaler  6.61589e+09  81338.1  0.223893
# 0    LinearRegression+Data_p3+MinMaxScaler  6.61594e+09  81338.4  0.223885
# 0    LinearRegression+Data_p3+RobustScaler  6.61564e+09  81336.6  0.223919
# 0            LinearRegression+Data_p3+None  6.61592e+09  81338.3  0.223888
# 0      CatBoostRegressor_encoded+Data+None  2.11564e+09    45996  0.754224
#
#       MSE_train    RMSE_train      MSE_test     RMSE_test  R2_train   R2_test
# 0  8.593945e+09  92703.532793  8.607589e+09  92777.092629  0.000000  0.000000
# 0  3.429410e+09  58561.160775  4.250756e+09  65197.825703  0.600950  0.506162
# 0  3.430432e+09  58569.890956  4.238983e+09  65107.470545  0.600832  0.507530
# 0  3.429926e+09  58565.572984  4.239003e+09  65107.628694  0.600890  0.507527
# 0  3.429308e+09  58560.291135  4.238063e+09  65100.403463  0.600962  0.507637
# 0  3.430676e+09  58571.975264  4.239123e+09  65108.544625  0.600803  0.507513
# 0  3.430781e+09  58572.866267  4.247854e+09  65175.560630  0.600791  0.506499
# 0  3.429926e+09  58565.572984  4.239003e+09  65107.628694  0.600890  0.507527
# 0  3.429517e+09  58562.078999  4.238075e+09  65100.501558  0.600938  0.507635
# 0  2.669495e+09  51667.155766  3.577984e+09  59816.250570  0.689375  0.584322
# 0  2.669454e+09  51666.755107  3.578128e+09  59817.457369  0.689380  0.584305
# 0  2.669508e+09  51667.277223  3.578931e+09  59824.165579  0.689373  0.584212
# 0  2.669497e+09  51667.179548  3.577963e+09  59816.077546  0.689375  0.584325
# 0  2.072165e+09  45521.042618  7.819983e+09  88430.669729  0.758881  0.091501
# 0  2.072203e+09  45521.461764  7.821388e+09  88438.610730  0.758876  0.091338
# 0  2.072171e+09  45521.102558  7.819300e+09  88426.806157  0.758880  0.091581
# 0  2.072166e+09  45521.055510  7.819960e+09  88430.539925  0.758881  0.091504
# 0  5.938367e+08  24368.764741  2.265174e+09  47593.847478  0.930901  0.736840

# %%
# %%time
models_results = model_fit_results(model_forest, 'RandomForestRegressor', [data_list[1]], scalers_for_gb, feats_not_to_scale, models_results)
# Out:
# Wall time: 50.5 s

# %%
models_results
# Out:
#                                      Model       CV_MSE  CV_RMSE     CV_R2  \
# 0                                 Baseline          NaN      NaN       NaN
# 0  LinearRegression+Data_lr+StandardScaler  3.63928e+09  60326.4  0.576941
# 0    LinearRegression+Data_lr+MinMaxScaler  3.64152e+09    60345  0.576679
# 0    LinearRegression+Data_lr+RobustScaler  3.63946e+09    60328  0.576915
# 0            LinearRegression+Data_lr+None  3.64017e+09  60333.8  0.576834
# 0     LinearRegression+Data+StandardScaler  3.64028e+09  60334.7  0.576822
# 0       LinearRegression+Data+MinMaxScaler   3.6413e+09  60343.2  0.576703
# 0       LinearRegression+Data+RobustScaler   3.6392e+09  60325.8  0.576944
# 0               LinearRegression+Data+None  3.63981e+09  60330.8  0.576875
# 0  LinearRegression+Data_p2+StandardScaler  3.08014e+09  55499.1   0.64224
# 0    LinearRegression+Data_p2+MinMaxScaler  3.07995e+09  55497.3  0.642264
# 0    LinearRegression+Data_p2+RobustScaler  3.08027e+09  55500.2  0.642226
# 0            LinearRegression+Data_p2+None  3.08025e+09    55500  0.642228
# 0  LinearRegression+Data_p3+StandardScaler  6.61589e+09  81338.1  0.223893
# 0    LinearRegression+Data_p3+MinMaxScaler  6.61594e+09  81338.4  0.223885
# 0    LinearRegression+Data_p3+RobustScaler  6.61564e+09  81336.6  0.223919
# 0            LinearRegression+Data_p3+None  6.61592e+09  81338.3  0.223888
# 0      CatBoostRegressor_encoded+Data+None  2.11564e+09    45996  0.754224
# 0          RandomForestRegressor+Data+None  2.38468e+09  48833.2  0.722864
#
#       MSE_train    RMSE_train      MSE_test     RMSE_test  R2_train   R2_test
# 0  8.593945e+09  92703.532793  8.607589e+09  92777.092629  0.000000  0.000000
# 0  3.429410e+09  58561.160775  4.250756e+09  65197.825703  0.600950  0.506162
# 0  3.430432e+09  58569.890956  4.238983e+09  65107.470545  0.600832  0.507530
# 0  3.429926e+09  58565.572984  4.239003e+09  65107.628694  0.600890  0.507527
# 0  3.429308e+09  58560.291135  4.238063e+09  65100.403463  0.600962  0.507637
# 0  3.430676e+09  58571.975264  4.239123e+09  65108.544625  0.600803  0.507513
# 0  3.430781e+09  58572.866267  4.247854e+09  65175.560630  0.600791  0.506499
# 0  3.429926e+09  58565.572984  4.239003e+09  65107.628694  0.600890  0.507527
# 0  3.429517e+09  58562.078999  4.238075e+09  65100.501558  0.600938  0.507635
# 0  2.669495e+09  51667.155766  3.577984e+09  59816.250570  0.689375  0.584322
# 0  2.669454e+09  51666.755107  3.578128e+09  59817.457369  0.689380  0.584305
# 0  2.669508e+09  51667.277223  3.578931e+09  59824.165579  0.689373  0.584212
# 0  2.669497e+09  51667.179548  3.577963e+09  59816.077546  0.689375  0.584325
# 0  2.072165e+09  45521.042618  7.819983e+09  88430.669729  0.758881  0.091501
# 0  2.072203e+09  45521.461764  7.821388e+09  88438.610730  0.758876  0.091338
# 0  2.072171e+09  45521.102558  7.819300e+09  88426.806157  0.758880  0.091581
# 0  2.072166e+09  45521.055510  7.819960e+09  88430.539925  0.758881  0.091504
# 0  5.938367e+08  24368.764741  2.265174e+09  47593.847478  0.930901  0.736840
# 0  3.210922e+08  17919.046563  2.399891e+09  48988.680683  0.962637  0.721189

# %%
# %%time
models_results = model_fit_results(model_lightgbm, 'LGBMRegressor', [data_list[1]], scalers_for_gb, feats_not_to_scale, models_results)
# Out:
# Wall time: 1.49 s

# %%
models_results
# Out:
#                                      Model       CV_MSE  CV_RMSE     CV_R2  \
# 0                                 Baseline          NaN      NaN       NaN
# 0  LinearRegression+Data_lr+StandardScaler  3.63928e+09  60326.4  0.576941
# 0    LinearRegression+Data_lr+MinMaxScaler  3.64152e+09    60345  0.576679
# 0    LinearRegression+Data_lr+RobustScaler  3.63946e+09    60328  0.576915
# 0            LinearRegression+Data_lr+None  3.64017e+09  60333.8  0.576834
# 0     LinearRegression+Data+StandardScaler  3.64028e+09  60334.7  0.576822
# 0       LinearRegression+Data+MinMaxScaler   3.6413e+09  60343.2  0.576703
# 0       LinearRegression+Data+RobustScaler   3.6392e+09  60325.8  0.576944
# 0               LinearRegression+Data+None  3.63981e+09  60330.8  0.576875
# 0  LinearRegression+Data_p2+StandardScaler  3.08014e+09  55499.1   0.64224
# 0    LinearRegression+Data_p2+MinMaxScaler  3.07995e+09  55497.3  0.642264
# 0    LinearRegression+Data_p2+RobustScaler  3.08027e+09  55500.2  0.642226
# 0            LinearRegression+Data_p2+None  3.08025e+09    55500  0.642228
# 0  LinearRegression+Data_p3+StandardScaler  6.61589e+09  81338.1  0.223893
# 0    LinearRegression+Data_p3+MinMaxScaler  6.61594e+09  81338.4  0.223885
# 0    LinearRegression+Data_p3+RobustScaler  6.61564e+09  81336.6  0.223919
# 0            LinearRegression+Data_p3+None  6.61592e+09  81338.3  0.223888
# 0      CatBoostRegressor_encoded+Data+None  2.11564e+09    45996  0.754224
# 0          RandomForestRegressor+Data+None  2.38468e+09  48833.2  0.722864
# 0                  LGBMRegressor+Data+None  2.21735e+09  47088.7  0.742382
#
#       MSE_train    RMSE_train      MSE_test     RMSE_test  R2_train   R2_test
# 0  8.593945e+09  92703.532793  8.607589e+09  92777.092629  0.000000  0.000000
# 0  3.429410e+09  58561.160775  4.250756e+09  65197.825703  0.600950  0.506162
# 0  3.430432e+09  58569.890956  4.238983e+09  65107.470545  0.600832  0.507530
# 0  3.429926e+09  58565.572984  4.239003e+09  65107.628694  0.600890  0.507527
# 0  3.429308e+09  58560.291135  4.238063e+09  65100.403463  0.600962  0.507637
# 0  3.430676e+09  58571.975264  4.239123e+09  65108.544625  0.600803  0.507513
# 0  3.430781e+09  58572.866267  4.247854e+09  65175.560630  0.600791  0.506499
# 0  3.429926e+09  58565.572984  4.239003e+09  65107.628694  0.600890  0.507527
# 0  3.429517e+09  58562.078999  4.238075e+09  65100.501558  0.600938  0.507635
# 0  2.669495e+09  51667.155766  3.577984e+09  59816.250570  0.689375  0.584322
# 0  2.669454e+09  51666.755107  3.578128e+09  59817.457369  0.689380  0.584305
# 0  2.669508e+09  51667.277223  3.578931e+09  59824.165579  0.689373  0.584212
# 0  2.669497e+09  51667.179548  3.577963e+09  59816.077546  0.689375  0.584325
# 0  2.072165e+09  45521.042618  7.819983e+09  88430.669729  0.758881  0.091501
# 0  2.072203e+09  45521.461764  7.821388e+09  88438.610730  0.758876  0.091338
# 0  2.072171e+09  45521.102558  7.819300e+09  88426.806157  0.758880  0.091581
# 0  2.072166e+09  45521.055510  7.819960e+09  88430.539925  0.758881  0.091504
# 0  5.938367e+08  24368.764741  2.265174e+09  47593.847478  0.930901  0.736840
# 0  3.210922e+08  17919.046563  2.399891e+09  48988.680683  0.962637  0.721189
# 0  7.882060e+08  28075.006244  2.338865e+09  48361.811269  0.908284  0.728279

# %%
X_train_ne = train_data_ne.drop(['DistrictId', 'Price'], axis=1)
X_test_ne = test_data_ne.drop(['DistrictId', 'Price'], axis=1)

# %%
model_catboost_ne = CatBoostRegressor(cat_features=cat_feats, silent=True)

# %%
# %%time
models_results = model_fit_results(model_catboost_ne, 'CatBoostRegressor_ne', [('Data_ne', X_train_ne, X_test_ne, y_train, y_test)], 
                                   scalers_for_gb, feats_not_to_scale, models_results)
# Out:
# Wall time: 17.6 s

# %%
models_results
# Out:
#                                      Model       CV_MSE  CV_RMSE     CV_R2  \
# 0                                 Baseline          NaN      NaN       NaN
# 0  LinearRegression+Data_lr+StandardScaler  3.63928e+09  60326.4  0.576941
# 0    LinearRegression+Data_lr+MinMaxScaler  3.64152e+09    60345  0.576679
# 0    LinearRegression+Data_lr+RobustScaler  3.63946e+09    60328  0.576915
# 0            LinearRegression+Data_lr+None  3.64017e+09  60333.8  0.576834
# 0     LinearRegression+Data+StandardScaler  3.64028e+09  60334.7  0.576822
# 0       LinearRegression+Data+MinMaxScaler   3.6413e+09  60343.2  0.576703
# 0       LinearRegression+Data+RobustScaler   3.6392e+09  60325.8  0.576944
# 0               LinearRegression+Data+None  3.63981e+09  60330.8  0.576875
# 0  LinearRegression+Data_p2+StandardScaler  3.08014e+09  55499.1   0.64224
# 0    LinearRegression+Data_p2+MinMaxScaler  3.07995e+09  55497.3  0.642264
# 0    LinearRegression+Data_p2+RobustScaler  3.08027e+09  55500.2  0.642226
# 0            LinearRegression+Data_p2+None  3.08025e+09    55500  0.642228
# 0  LinearRegression+Data_p3+StandardScaler  6.61589e+09  81338.1  0.223893
# 0    LinearRegression+Data_p3+MinMaxScaler  6.61594e+09  81338.4  0.223885
# 0    LinearRegression+Data_p3+RobustScaler  6.61564e+09  81336.6  0.223919
# 0            LinearRegression+Data_p3+None  6.61592e+09  81338.3  0.223888
# 0      CatBoostRegressor_encoded+Data+None  2.11564e+09    45996  0.754224
# 0          RandomForestRegressor+Data+None  2.38468e+09  48833.2  0.722864
# 0                  LGBMRegressor+Data+None  2.21735e+09  47088.7  0.742382
# 0        CatBoostRegressor_ne+Data_ne+None  2.11873e+09  46029.6  0.753884
#
#       MSE_train    RMSE_train      MSE_test     RMSE_test  R2_train   R2_test
# 0  8.593945e+09  92703.532793  8.607589e+09  92777.092629  0.000000  0.000000
# 0  3.429410e+09  58561.160775  4.250756e+09  65197.825703  0.600950  0.506162
# 0  3.430432e+09  58569.890956  4.238983e+09  65107.470545  0.600832  0.507530
# 0  3.429926e+09  58565.572984  4.239003e+09  65107.628694  0.600890  0.507527
# 0  3.429308e+09  58560.291135  4.238063e+09  65100.403463  0.600962  0.507637
# 0  3.430676e+09  58571.975264  4.239123e+09  65108.544625  0.600803  0.507513
# 0  3.430781e+09  58572.866267  4.247854e+09  65175.560630  0.600791  0.506499
# 0  3.429926e+09  58565.572984  4.239003e+09  65107.628694  0.600890  0.507527
# 0  3.429517e+09  58562.078999  4.238075e+09  65100.501558  0.600938  0.507635
# 0  2.669495e+09  51667.155766  3.577984e+09  59816.250570  0.689375  0.584322
# 0  2.669454e+09  51666.755107  3.578128e+09  59817.457369  0.689380  0.584305
# 0  2.669508e+09  51667.277223  3.578931e+09  59824.165579  0.689373  0.584212
# 0  2.669497e+09  51667.179548  3.577963e+09  59816.077546  0.689375  0.584325
# 0  2.072165e+09  45521.042618  7.819983e+09  88430.669729  0.758881  0.091501
# 0  2.072203e+09  45521.461764  7.821388e+09  88438.610730  0.758876  0.091338
# 0  2.072171e+09  45521.102558  7.819300e+09  88426.806157  0.758880  0.091581
# 0  2.072166e+09  45521.055510  7.819960e+09  88430.539925  0.758881  0.091504
# 0  5.938367e+08  24368.764741  2.265174e+09  47593.847478  0.930901  0.736840
# 0  3.210922e+08  17919.046563  2.399891e+09  48988.680683  0.962637  0.721189
# 0  7.882060e+08  28075.006244  2.338865e+09  48361.811269  0.908284  0.728279
# 0  5.827384e+08  24139.975533  2.286303e+09  47815.300244  0.932192  0.734385

# %%
models_results = models_results.reset_index().drop('index', axis=1)
models_results
# Out:
#                                       Model       CV_MSE  CV_RMSE     CV_R2  \
# 0                                  Baseline          NaN      NaN       NaN
# 1   LinearRegression+Data_lr+StandardScaler  3.63928e+09  60326.4  0.576941
# 2     LinearRegression+Data_lr+MinMaxScaler  3.64152e+09    60345  0.576679
# 3     LinearRegression+Data_lr+RobustScaler  3.63946e+09    60328  0.576915
# 4             LinearRegression+Data_lr+None  3.64017e+09  60333.8  0.576834
# 5      LinearRegression+Data+StandardScaler  3.64028e+09  60334.7  0.576822
# 6        LinearRegression+Data+MinMaxScaler   3.6413e+09  60343.2  0.576703
# 7        LinearRegression+Data+RobustScaler   3.6392e+09  60325.8  0.576944
# 8                LinearRegression+Data+None  3.63981e+09  60330.8  0.576875
# 9   LinearRegression+Data_p2+StandardScaler  3.08014e+09  55499.1   0.64224
# 10    LinearRegression+Data_p2+MinMaxScaler  3.07995e+09  55497.3  0.642264
# 11    LinearRegression+Data_p2+RobustScaler  3.08027e+09  55500.2  0.642226
# 12            LinearRegression+Data_p2+None  3.08025e+09    55500  0.642228
# 13  LinearRegression+Data_p3+StandardScaler  6.61589e+09  81338.1  0.223893
# 14    LinearRegression+Data_p3+MinMaxScaler  6.61594e+09  81338.4  0.223885
# 15    LinearRegression+Data_p3+RobustScaler  6.61564e+09  81336.6  0.223919
# 16            LinearRegression+Data_p3+None  6.61592e+09  81338.3  0.223888
# 17      CatBoostRegressor_encoded+Data+None  2.11564e+09    45996  0.754224
# 18          RandomForestRegressor+Data+None  2.38468e+09  48833.2  0.722864
# 19                  LGBMRegressor+Data+None  2.21735e+09  47088.7  0.742382
# 20        CatBoostRegressor_ne+Data_ne+None  2.11873e+09  46029.6  0.753884
#
#        MSE_train    RMSE_train      MSE_test     RMSE_test  R2_train   R2_test
# 0   8.593945e+09  92703.532793  8.607589e+09  92777.092629  0.000000  0.000000
# 1   3.429410e+09  58561.160775  4.250756e+09  65197.825703  0.600950  0.506162
# 2   3.430432e+09  58569.890956  4.238983e+09  65107.470545  0.600832  0.507530
# 3   3.429926e+09  58565.572984  4.239003e+09  65107.628694  0.600890  0.507527
# 4   3.429308e+09  58560.291135  4.238063e+09  65100.403463  0.600962  0.507637
# 5   3.430676e+09  58571.975264  4.239123e+09  65108.544625  0.600803  0.507513
# 6   3.430781e+09  58572.866267  4.247854e+09  65175.560630  0.600791  0.506499
# 7   3.429926e+09  58565.572984  4.239003e+09  65107.628694  0.600890  0.507527
# 8   3.429517e+09  58562.078999  4.238075e+09  65100.501558  0.600938  0.507635
# 9   2.669495e+09  51667.155766  3.577984e+09  59816.250570  0.689375  0.584322
# 10  2.669454e+09  51666.755107  3.578128e+09  59817.457369  0.689380  0.584305
# 11  2.669508e+09  51667.277223  3.578931e+09  59824.165579  0.689373  0.584212
# 12  2.669497e+09  51667.179548  3.577963e+09  59816.077546  0.689375  0.584325
# 13  2.072165e+09  45521.042618  7.819983e+09  88430.669729  0.758881  0.091501
# 14  2.072203e+09  45521.461764  7.821388e+09  88438.610730  0.758876  0.091338
# 15  2.072171e+09  45521.102558  7.819300e+09  88426.806157  0.758880  0.091581
# 16  2.072166e+09  45521.055510  7.819960e+09  88430.539925  0.758881  0.091504
# 17  5.938367e+08  24368.764741  2.265174e+09  47593.847478  0.930901  0.736840
# 18  3.210922e+08  17919.046563  2.399891e+09  48988.680683  0.962637  0.721189
# 19  7.882060e+08  28075.006244  2.338865e+09  48361.811269  0.908284  0.728279
# 20  5.827384e+08  24139.975533  2.286303e+09  47815.300244  0.932192  0.734385

# %%
models_results.to_csv('../Data/models_results.csv', index=False)
